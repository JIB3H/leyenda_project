# %% [markdown]
# # <center>Annotation d'images<br /> Workshop</center>
#
# ![logoEI_1_6.jpg](attachment:logoEI_1_6.jpg)
# Concepteur : Nassim HADDAM
# </div>

# %% [markdown]
# L'objectif de de ce workshop est de vous faire acquérir les notions nécessaires pour effectuer le workshop d'[annotation d'images](https://fr.wikipedia.org/wiki/Annotation_automatique_d%27images) (ou sous-titrage d'images). Dans ce workshop, vous allez devoir utiliser les CNNs (pour création d’attributs utiles à l’annotation) ainsi que les RNNs (pour faire l’annotation à proprement parler). Vous allez aussi devoir faire **beaucoup** de prétraitements. Ce workshop portera essentiellement sur cette partie et donnera des indications sur l'architecture du réseau qui servira à faire de l'annotation. On commencera d'abord par importer les bibliothèques qui nous intéressent.

# %% [markdown]
# Vous devez, donc, ré-exécuter les cellules correspondant à la préparation des données du workshop précédent en allant du chargement des données jusqu'au prétraitements des images et des annotations.
# <br><br>
# <b>Imports</b>

# %%
import tensorflow as tf

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import collections
import random
import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle
from tqdm import tqdm

# %% [markdown]
# <b>Chargement des données</b>

# %%
# Chemin du fichier d'annotations
annotation_file = os.path.abspath('.')+"/annotations/captions_train2017.json"

# Chemin du dossier contenant les images à annoter
image_folder = '/train2017/'
PATH = os.path.abspath('.') + image_folder

# Lecture du fichier d'annotation
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# Grouper toutes les annotations ayant le meme identifiant.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    # marquer le debut et la fin de chaque annotation
    caption = f"<start> {val['caption']} <end>"
    # L'identifiant d'une image fait partie de son chemin d'accès
    # image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path = PATH + '%012d.jpg' % (val['image_id'])
    # Rajout du caption associé à image_path
    image_path_to_caption[image_path].append(caption)
    
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
train_image_paths = image_paths[:100000]
print(len(train_image_paths))

# Liste de toutes les annotations
train_captions = []
# Liste de tous les noms de fichiers des images dupliquées (en nombre d'annotations par image)
img_name_vector = []

for image_path in train_image_paths:
    caption_list = image_path_to_caption[image_path]
    # Rajout de caption_list dans train_captions
    train_captions.extend(caption_list)
    # Rajout de image_path dupliquée len(caption_list) fois
    img_name_vector.extend([image_path] * len(caption_list))

print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# 100000
# <start> A group of buildings in a street area with cars and trees. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x640 at 0x20A1BA41130>

# %%
len(image_paths)
# Out:
# 118287

# %%
# Définition de la fonction load_image
def load_image(image_path):
    """
    La fonction load_image a pour entrée le chemin d'une image et pour sortie un couple
    contenant l'image traitée ainsi que son chemin d'accès.
    La fonction load_image effectue les traitement suivant:
        1. Chargement du fichier correspondant au chemin d'accès image_path
        2. Décodage de l'image en RGB.
        3. Redimensionnement de l'image en taille (299, 299).
        4. Normalisation des pîxels de l'image entre -1 et 1
    """
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
# Telechargement du modèle InceptionV3 pré-entrainé avec la cassification sur ImageNet
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
# Creation d'une variable qui sera l'entrée du nouveau modèle de pre-traitement d'images
new_input = image_model.input

# récupérer la dernière couche caché qui contient l'image en representation compacte
hidden_layer = image_model.layers[-1].output

# Modèle qui calcule une representation dense des images avec InceptionV3
image_features_extract_model = tf.keras.Model(new_input, hidden_layer)



# Pré-traitement des images
# Prendre les noms des images
encode_train = sorted(set(img_name_vector))

# Creation d'une instance de "tf.data.Dataset" partant des noms des images 
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
# Division du données en batchs après application du pré-traitement fait par load_image
image_dataset = image_dataset.map(
    load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(16)

# Parcourir le dataset batch par batch pour effectuez le pré-traitement d'InceptionV3
for img, path in tqdm(image_dataset):
    # Pré-traitement du batch (de taille (16,8,8,2048)) courant par InceptionV3 
    batch_features = image_features_extract_model(img)
    # Resize du batch de taille (16,8,8,2048) en taille (16,64,2048)
    batch_features = tf.reshape(batch_features,
                                (batch_features.shape[0], -1, batch_features.shape[3]))
    # Parcourir le batch courant et stocker le chemin ainsi que le batch avec np.save()
    for bf, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        # (chemin de l'image associe a sa nouvelle representation , representation de l'image)
        np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 6250/6250 [14:11<00:00,  7.34it/s]

# %% [markdown]
# **Pré-traitement des annotations**

# %%
# Trouver la taille maximale 
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# Chosir les 5000 mots les plus frequents du vocabulaire
top_k = 5000
#La classe Tokenizer permet de faire du pre-traitement de texte pour reseau de neurones 
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                    oov_token="<unk>",
                                                    filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
# Construit un vocabulaire en se basant sur la liste train_captions
tokenizer.fit_on_texts(train_captions)

# Créer le token qui sert à remplir les annotations pour egaliser leurs longueur
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# Creation des vecteurs(liste de token entiers) à partir des annotations (liste de mots)
train_seqs = tokenizer.texts_to_sequences(train_captions)
#A COMPLETER

# Remplir chaque vecteur à jusqu'à la longueur maximale des annotations
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')
#A COMPLETER

# Calcule la longueur maximale qui est utilisée pour stocker les poids d'attention 
# Elle servira plus tard pour l'affichage lors de l'évaluation
max_length = calc_max_length(train_seqs)

# %% [markdown]
# # 1 Formation du jeu d'entrainement et de test :
# Vous devez ensuite séparer le dataset en deux partie : un jeu d'entrainement et un jeu de test. Le code qui effectue ces opérations est détaillé dans la cellule suivante.

# %%
img_to_cap_vector = collections.defaultdict(list)
# Creation d'un dictionnaire associant les chemins des images avec (fichier .npy) aux annotationss
# Les images sont dupliquées car il y a plusieurs annotations par image
print(len(img_name_vector), len(cap_vector))
for img, cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

"""
Création des datasets de formation et de validation en utilisant 
un fractionnement 80-20 de manière aléatoire
""" 
# Prendre les clés (noms des fichiers d'images traites), *celles-ci ne seront pas dupliquées*
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)
# Diviser des indices en entrainement et test
slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

"""
Les jeux d'entrainement et de tests sont sous forme
de listes contenants les mappings :(image prétraitée ---> jeton d'annotation(mot) )
"""

# Boucle pour construire le jeu d'entrainement
img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
    capt_len = len(img_to_cap_vector[imgt])
    # Duplication des images en le nombre d'annotations par image
    img_name_train.extend([imgt] * capt_len)
    cap_train.extend(img_to_cap_vector[imgt])

# Boucle pour construire le jeu de test
img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
    capv_len = len(img_to_cap_vector[imgv])
    img_name_val.extend([imgv] * capv_len)
    # Duplication des images en le nombre d'annotations par image
    cap_val.extend(img_to_cap_vector[imgv])

len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# 500262 500262
# (400210, 400210, 100052, 100052)

# %% [markdown]
# Création d’un jeu de données d’entrainement représenté par une instance [`tf.data.Dataset`](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) partant du jeu de données de base (les noms des fichiers et des annotations du jeu d’entrainement). La classe `tf.data.Dataset` sert à représenter des jeu de données volumineux et facilitent les prétraitements de ceux-ci.

# %%
# N'hésitez pas à modifier ces paramètres en fonction de votre machine
BATCH_SIZE = 64 # taille du batch
BUFFER_SIZE = 1000 # taille du buffer pour melanger les donnes
embedding_dim = 256
units = 512 # Taille de la couche caché dans le RNN
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE

# La forme du vecteur extrait à partir d'InceptionV3 est (64, 2048)
# Les deux variables suivantes representent la forme de ce vecteur
features_shape = 2048
attention_features_shape = 64

# Fonction qui charge les fichiers numpy des images prétraitées
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# Creation d'un dataset de "Tensor"s (sert à representer de grands dataset)
# Le dataset est cree a partir de "img_name_train" et "cap_train"
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# L'utilisation de map permet de charger les fichiers numpy (possiblement en parallèle)
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
        map_func, [item1, item2], [tf.float32, tf.int32]),
        num_parallel_calls=tf.data.experimental.AUTOTUNE)

# Melanger les donnees et les diviser en batchs
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# # 2 Le modèle :
# Par rapport au modèle, la dernière couche convolutive d'`InceptionV3` est de la forme `(8, 8, 2048)`. Ce vecteur a été remodelé en la forme `(64, 2048)` lors de du stockage au niveau du disque. Ce vecteur est ensuite passé à travers l'encodeur CNN (qui se compose d'une seule couche entièrement connectée). Le RNN s'occupera de prédire pour ce vecteur le mot suivant dans l'annotation. [L'image](https://github.com/Hvass-Labs/TensorFlow-Tutorials/blob/master/22_Image_Captioning.ipynb) ci-dessous reprend un exemple d'une architecture très basique d'un système d'annotation utilisant un CNN et un RNN.
#
# ![22_image_captioning_flowchart.png](attachment:22_image_captioning_flowchart.png)
#
# Dans cet exemple le captioning se fait de cette façon:
# <ul>
#     <li>L'image est passée à travers le CNN pour avoir une représentation compacte de celui-ci. Cette représentation est retournée par la couche `Dense 2` de taille 4096.</li>
#     <li>Cette représentation est réduite en la passant à la couche dense `Dense Map` pour etre mise en entrée comme etat caché initial aux cellules du RNN.</li>
#     <li>La partie RNN est composée de <a href="https://openclassrooms.com">GRU</a> (Gated Reccurent Unit). Cette partie est constituée de 3 couches. Une couche représentant de manière assez sommaire un niveau d'abstraction du langage. </li>
#     <li>Le RNN a en entrée l'annotation ainsi que l'image en forme compacte, et retourne pour chaque colonne le mot suivant le mot en entrée au niveau de la colonne.</li>
#     <li>Les annotations sont représentées en liste de mot. Cette liste est inexploitable par le RNN, elle est donc passée à un module qui remplace chaque mot par un entier (ou jeton entier), puis par un autre module qui projette chaque jeton en un vecteur dont les éléments sont entre -1 et 1.</li>
# </ul>
#
# Votre système d'annotation suivra de manière assez globale, le même principe que montrée dans l'image ci-dessous, néanmoins il contiendra des différences essentielles le distinguant de cet exemple. La système contiendra, notamment, un mécanisme d'attention (expliqué dans [article](https://arxiv.org/pdf/1502.03044.pdf) et dans [la video](https://www.youtube.com/watch?v=uCSTpOLMC48&list=WL&index=257)) dont la fonction est d'amener le réseau de neurones à donner une plus grande importance dans ses prédictions de l'annotation aux parties de l'images les plus parlantes et les plus pertinentes.

# %% [markdown]
# **L'encodeur CNN :**
#
# L'encodeur CNN produit une représentation adéquate de l'image qu'il transmet au décodeur RNN pour la légender. Le CNN a en entrée les caractéristiques des images déjà prétraitées par InceptionV3 et stockées sur disque.
#
# Petite remarque, dans la partie CNN de ce réseau de neurones, la dernière couche convolutive n’est pas aplatie comme dans le cas du précédent workshop sur les CNNs. Rappelez-vous que les images issues du prétraitement par InceptionV3 étaient de la forme 8x8x2048. Ces images ont été remodelées pour avoir la taille 64x2048. Cela signifie que cette représentation contient pour chacune des 64 positions de l’image prétraitée les 2048 caractéristiques extraites par InveptoinV3. Et donc, l’entrée du décodeur CNN est un batch ou chaque élément est constitué des 2048 caractéristiques des 64 positions de l’image prétraitée (qui était à l’origine 8x8). La couche dense qui suit calcule une nouvelle représentation de l’image de taille 64x256 ou chaque position de l’image a donc 256 caractéristiques. Les poids sont les mêmes pour les neurones de mêmes position qui se trouvent sur la même colonne dans l’image prétraitée (qui sont associées à la même caractéristique de l’image). Ceci provient de la manière qu’a la [couche dense]( https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) de gérer les opérations matricielles dans tensorflow.
#
# L’avantage de cette représentation par rapport à la représentation aplatie est de préserver de l’information spatiale au niveau des couches du réseau de neurones. Ceci permettra au mécanisme d’attention de la partie RNN de détecter les positions intéressantes au niveau de l’image et de renseigner l’algorithme sur quelle zone il devra porter le plus d’importance pour légender l’image.

# %%
class CNN_Encoder(tf.keras.Model):
    # Comme les images sont déjà prétraités par InceptionV3 est représenté sous forme compacte
    # L'encodeur CNN ne fera que transmettre ces caractéristiques à une couche dense
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # forme après fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %% [markdown]
# **Le mécanisme d'attention :**
#
# Le mécanisme d’attention ressemble beaucoup à une cellule [RNN classique]( https://fr.wikipedia.org/wiki/R%C3%A9seau_de_neurones_r%C3%A9currents), mais avec quelques différences. La partie de l’attention a en entrée la représentation de l’image prétraitée retournée par le CNN ainsi que la valeur courante de l’état cachée du GRU, et en sortie le **vecteur du contexte** qui reflète les caractéristiques les plus importantes de l’image. Une étape intermédiaire pour calculer ce vecteur consiste à calculer les **poids d’attention** qui représentent l’importance de chaque position de l’image (il y en a 64) dans la prédiction de son annotation.
#
# La représentation de l’image donnée en entrée est transformée au début de la même manière que pour le CNN en la passant à une couche dense de taille `units`. De même, l’état caché est aussi passé à une couche dense de taille `units`. La nouvelle représentation de l’image est ensuite additionnée à l’état caché puis passée à une fonction d’activation de type [`tanh`](https://fr.wikipedia.org/wiki/Tangente_hyperbolique) comme pour les cellules classiques de RNN. À ce niveau-là, on aura une représentation des données de taille `64xunits` contenant un mélange d’informations sur l’image et sur le texte de l’annotation. Un score est ensuite associé à chacune des positions en passant cette représentation à une couche dense. Ces scores sont normalisés avec une couche softmax pour produire le vecteur des **poids d’attention**.
#
# Finalement, chaque caractéristique de la représentation de l’image en entrée sera multipliée (pondérée) par le vecteur d’attention. Après quoi, on prend la somme de chaque caractéristique le long des positions (les lignes de la représentation) pour former le **vecteur du contexte**.
#
# De façon globale, on peut dire que le vecteur d’attention dépend de scores qui sont appris à partir d’une représentation spatiale et textuelle de l’image. Ce vecteur d’attention renvoie la pertinence de chaque position et sert à calculer le vecteur du contexte qui nous donnera l’importance des caractéristiques de l’image.

# %%
class BahdanauAttention(tf.keras.Model):
        def __init__(self, units):
                super(BahdanauAttention, self).__init__()
                self.W1 = tf.keras.layers.Dense(units)
                self.W2 = tf.keras.layers.Dense(units)
                self.V = tf.keras.layers.Dense(1)

        def call(self, features, hidden):
                # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

                # hidden shape == (batch_size, hidden_size)
                # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
                hidden_with_time_axis = tf.expand_dims(hidden, 1)
                
                # attention_hidden_layer shape == (batch_size, 64, units)
                attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                                        self.W2(hidden_with_time_axis)))
                # score shape == (batch_size, 64, 1)
                # This gives you an unnormalized score for each image feature.
                score = self.V(attention_hidden_layer)

                # attention_weights shape == (batch_size, 64, 1)
                attention_weights = tf.nn.softmax(score, axis=1)

                # context_vector shape after sum == (batch_size, hidden_size)
                context_vector = attention_weights * features
                context_vector = tf.reduce_sum(context_vector, axis=1)

                return context_vector, attention_weights

# %% [markdown]
# **Le décodeur RNN :**
#
# Le rôle du décodeur RNN est d’utiliser la représentation prétraitée de l’image de prédire sa légende mot par mot. Ce RNN à une seule cellule de type [GRU]( https://en.wikipedia.org/wiki/Gated_recurrent_unit). Le GRU a un état caché qui représente la mémoire des derniers éléments vu par celui-ci. Le GRU met à jour son état avant de le retourner, pour cela il utilise certains mécanismes de mémorisation qui sont assez sophistiqués.
#
# Le décodeur est structuré comme suit, à chaque appel du RNN, le mot courant ainsi que la représentation de l’image et l’état caché du GRU sont donnés en entrée du RNN. Comme les mots sont représentés par des entiers, on doit faire passer ceux-ci par une couche dite [embedding layer]( https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding) qui se chargera de calculer une représentation vectorielle de taille `output_dim` partant du nombre représentant le mot.
#
# À côté de ça, le mécanisme d’attention fournit un vecteur représentant **le contexte** de l’image c-à-d un vecteur qui nous renseigne sur les caractéristiques dominantes de l’image. Ce vecteur est calculé par un appel du mécanisme d’attention en lui fournissant en entrée les caractéristiques de l’image encodées par le CNN ainsi que l’état caché du GRU qui résume l’historique des mots vues par le RNN jusqu’à présent.
#
# Ensuite, le mot courant et le contexte sont concaténée pour former le vecteur d’entrée du GRU qui à son tour calcule l’état à l’étape suivante. Cet état est passée par une couche dense de taille `units` puis la sortie de cette couche est passée à une autre couche dense de taille `vocab_size` qui retourne le score associé à chaque mot du vocabulaire afin de prédire le mot suivant.

# %%
class RNN_Decoder(tf.keras.Model):
        def __init__(self, embedding_dim, units, vocab_size):
                super(RNN_Decoder, self).__init__()
                self.units = units
                self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
                self.gru = tf.keras.layers.GRU(self.units,
                                        return_sequences=True,
                                        return_state=True,
                                        recurrent_initializer='glorot_uniform')
                #Couche dense qui aura pour entrée la sortie du GRU
                self.fc1 = tf.keras.layers.Dense(self.units)
                # Dernière couche dense
                self.fc2 = tf.keras.layers.Dense(vocab_size)
                self.attention = BahdanauAttention(self.units)

        def call(self, x, features, hidden):
                # L'attention est defini par un modèle a part
                context_vector, attention_weights = self.attention(features, hidden)
                # Passage du mot courant à la couche embedding
                x = self.embedding(x)
                # Concaténation
                x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
                # Passage du vecteur concaténé à la gru
                output, state = self.gru(x)
                # Couche dense
                x = self.fc1(output)
                x = tf.reshape(x, (-1, x.shape[2]))
                # Couche dense
                x = self.fc2(x)
        
                return x, state, attention_weights
        def reset_state(self, batch_size):
                return tf.zeros((batch_size, self.units))

# %% [markdown]
# **Combiner la partie encodeur et décodeur :**
#
# Vous devez compléter la partie du code pour la création de l'encodeur et du décodeur.

# %%
# Création de l'encodeur
encoder = CNN_Encoder(embedding_dim)
# Création du décodeur
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
# Optimiseur ADAM
optimizer = tf.keras.optimizers.Adam()
# La fonction de perte
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# Pour garder la trace de votre apprentissage et la sauvegarder, vous pouvez utiliser la classe [`tf.train.Checkpoint`](https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint).

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %% [markdown]
# Initialisation de l'époque de début d’entrainement dans `start_epoch`. La classe `tf.train.Checkpoint` permet de poursuivre l’entrainement là ou vous l’avez laissé s’il avait été interrompu auparavant.

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # Restaurer le dernier checkpoint dans checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# # 3 Entrainement et test :
# Vous implémenterez ensuite les fonctions `train_step` et `evaluate` :
#
# - La fonction `train_step` représente une étape de l'entrainement du réseau. Elle est composée de l'évaluation par l'encodeur du vecteur pré-calculé par InceptionV3. La sortie de cette étape sera transmise au décodeur qui se charge de prédire l'annotation mot par mot. La boucle pour prédire chaque mot et calculer la perte associée devra être implémenté dans cette fonction.
# - La fonction `evaluate` servira à évaluer les performances du réseau sur le jeu de test. Elle est donc similaire à la fonction `train_step` sauf que la partie calcul de la fonction de perte est absente car il n'agit pas d'entrainer le réseau.</li>
#
# Enfin, vous devez implémenter la partie du code qui fait l'entrainement et le test. Précisons que l'entrainement se fait ici par batch d'images.
#
# # 3.1 Entrainement
# La fonction qui permet d'achever une étape d'entrainement sur un batch d'images est `train_step`. La fonction a en entrée un batch d'images prétraitées ainsi que leurs annotations et retourne la perte associée à ce batch.
#
# L'état caché de la partie RNN est initialisé ainsi que le mot de départ avec le token de début. Les caractéristiques de l'image sont ensuite extraites par l’encodeur. Après cela, on parcourt le batch mot par mot pour prédire le mot suivant à l'aide du décodeur. Le décodeur utilise l'état caché, les caractéristiques de l'image ainsi que le mot précédent pour prédire le mot courant. Le décodeur met à jour l'état caché et le retourne ainsi que les prédictions du batch. La perte est calculée à partir des prédictions retournées par le décodeur et les annotations associées au batch.
#
# Finalement, la perte globale ainsi que le gradient sont calculés et le réseau est mis à jour.

# %%
loss_plot = []
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # Initialisation de l'état caché pour chaque batch
    hidden = decoder.reset_state(batch_size=target.shape[0])
    
    # Initialiser l'entrée du décodeur
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)
    
    with tf.GradientTape() as tape: # Offre la possibilité de calculer le gradient du loss
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # Prédiction des i'èmes mot du batch avec le décodeur
            predictions, hidden, _ = decoder(dec_input, features, hidden)
            loss += loss_function(target[:, i], predictions)

            # Le mot correct à l'étap i est donné en entrée à l'étape (i+1)
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %% [markdown]
# Le code global contenant la boucle d'entrainement est présenté ci-dessous. Cette boucle parcours le jeu de données d'entrainement batch par batch et entraine le réseaux avec ceux-ci.

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0
    
    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # sauvegarde de la perte
    loss_plot.append(total_loss / num_steps)

    if epoch % 1 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1, total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

# Affichage de la courbe d'entrainement
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()
# Out:
# Epoch 8 Batch 0 Loss 0.4994
# Epoch 8 Batch 100 Loss 0.4496
# Epoch 8 Batch 200 Loss 0.4385
# Epoch 8 Batch 300 Loss 0.4451
# Epoch 8 Batch 400 Loss 0.4339
# Epoch 8 Batch 500 Loss 0.4300
# Epoch 8 Batch 600 Loss 0.4192
# Epoch 8 Batch 700 Loss 0.4459
# Epoch 8 Batch 800 Loss 0.4532
# Epoch 8 Batch 900 Loss 0.4445
# Epoch 8 Batch 1000 Loss 0.4391
# Epoch 8 Batch 1100 Loss 0.4224
# Epoch 8 Batch 1200 Loss 0.4310
# Epoch 8 Batch 1300 Loss 0.4415
# Epoch 8 Batch 1400 Loss 0.4524
# Epoch 8 Batch 1500 Loss 0.3887
# Epoch 8 Batch 1600 Loss 0.4563
# Epoch 8 Batch 1700 Loss 0.4351
# Epoch 8 Batch 1800 Loss 0.4271
# Epoch 8 Batch 1900 Loss 0.4748
# Epoch 8 Batch 2000 Loss 0.4508
# Epoch 8 Batch 2100 Loss 0.4564
# Epoch 8 Batch 2200 Loss 0.4468
# Epoch 8 Batch 2300 Loss 0.4442
# Epoch 8 Batch 2400 Loss 0.4278
# Epoch 8 Batch 2500 Loss 0.4151
# Epoch 8 Batch 2600 Loss 0.3984
# Epoch 8 Batch 2700 Loss 0.4522
# Epoch 8 Batch 2800 Loss 0.4314
# Epoch 8 Batch 2900 Loss 0.4556
# Epoch 8 Batch 3000 Loss 0.4159
# Epoch 8 Batch 3100 Loss 0.4450
# Epoch 8 Batch 3200 Loss 0.4415
# Epoch 8 Batch 3300 Loss 0.4149
# Epoch 8 Batch 3400 Loss 0.4439
# Epoch 8 Batch 3500 Loss 0.4481
# Epoch 8 Batch 3600 Loss 0.4389
# Epoch 8 Batch 3700 Loss 0.4469
# Epoch 8 Batch 3800 Loss 0.4588
# Epoch 8 Batch 3900 Loss 0.4499
# Epoch 8 Batch 4000 Loss 0.4062
# Epoch 8 Batch 4100 Loss 0.4380
# Epoch 8 Batch 4200 Loss 0.4523
# Epoch 8 Batch 4300 Loss 0.4264
# Epoch 8 Batch 4400 Loss 0.4073
# Epoch 8 Batch 4500 Loss 0.4639
# Epoch 8 Batch 4600 Loss 0.4455
# Epoch 8 Batch 4700 Loss 0.4656
# Epoch 8 Batch 4800 Loss 0.4204
# Epoch 8 Batch 4900 Loss 0.4275
# Epoch 8 Batch 5000 Loss 0.4603
# Epoch 8 Batch 5100 Loss 0.4501
# Epoch 8 Batch 5200 Loss 0.3858
# Epoch 8 Batch 5300 Loss 0.4764
# Epoch 8 Batch 5400 Loss 0.4801
# Epoch 8 Batch 5500 Loss 0.4642
# Epoch 8 Batch 5600 Loss 0.4833
# Epoch 8 Batch 5700 Loss 0.4482
# Epoch 8 Batch 5800 Loss 0.4266
# Epoch 8 Batch 5900 Loss 0.4305
# Epoch 8 Batch 6000 Loss 0.4577
# Epoch 8 Batch 6100 Loss 0.3951
# Epoch 8 Batch 6200 Loss 0.4256
# Epoch 8 Loss 0.440498
# Time taken for 1 epoch 1644.7761158943176 sec
#
# Epoch 9 Batch 0 Loss 0.4413
# Epoch 9 Batch 100 Loss 0.4209
# Epoch 9 Batch 200 Loss 0.4321
# Epoch 9 Batch 300 Loss 0.4065
# Epoch 9 Batch 400 Loss 0.4629
# Epoch 9 Batch 500 Loss 0.4486
# Epoch 9 Batch 600 Loss 0.4231
# Epoch 9 Batch 700 Loss 0.4027
# Epoch 9 Batch 800 Loss 0.3751
# Epoch 9 Batch 900 Loss 0.4192
# Epoch 9 Batch 1000 Loss 0.4227
# Epoch 9 Batch 1100 Loss 0.4119
# Epoch 9 Batch 1200 Loss 0.4637
# Epoch 9 Batch 1300 Loss 0.4002
# Epoch 9 Batch 1400 Loss 0.4903
# Epoch 9 Batch 1500 Loss 0.4512
# Epoch 9 Batch 1600 Loss 0.4168
# Epoch 9 Batch 1700 Loss 0.4309
# Epoch 9 Batch 1800 Loss 0.4647
# Epoch 9 Batch 1900 Loss 0.4328
# Epoch 9 Batch 2000 Loss 0.3971
# Epoch 9 Batch 2100 Loss 0.4515
# Epoch 9 Batch 2200 Loss 0.4352
# Epoch 9 Batch 2300 Loss 0.4399
# Epoch 9 Batch 2400 Loss 0.4493
# Epoch 9 Batch 2500 Loss 0.4873
# Epoch 9 Batch 2600 Loss 0.4398
# Epoch 9 Batch 2700 Loss 0.4074
# Epoch 9 Batch 2800 Loss 0.4500
# Epoch 9 Batch 2900 Loss 0.5056
# Epoch 9 Batch 3000 Loss 0.4462
# Epoch 9 Batch 3100 Loss 0.4211
# Epoch 9 Batch 3200 Loss 0.4250
# Epoch 9 Batch 3300 Loss 0.4285
# Epoch 9 Batch 3400 Loss 0.3967
# Epoch 9 Batch 3500 Loss 0.4470
# Epoch 9 Batch 3600 Loss 0.3966
# Epoch 9 Batch 3700 Loss 0.4108
# Epoch 9 Batch 3800 Loss 0.4383
# Epoch 9 Batch 3900 Loss 0.4100
# Epoch 9 Batch 4000 Loss 0.4346
# Epoch 9 Batch 4100 Loss 0.3931
# Epoch 9 Batch 4200 Loss 0.4453
# Epoch 9 Batch 4300 Loss 0.4504
# Epoch 9 Batch 4400 Loss 0.4345
# Epoch 9 Batch 4500 Loss 0.4458
# Epoch 9 Batch 4600 Loss 0.4235
# Epoch 9 Batch 4700 Loss 0.4795
# Epoch 9 Batch 4800 Loss 0.4431
# Epoch 9 Batch 4900 Loss 0.4211
# Epoch 9 Batch 5000 Loss 0.4321
# Epoch 9 Batch 5100 Loss 0.4747
# Epoch 9 Batch 5200 Loss 0.4215
# Epoch 9 Batch 5300 Loss 0.4376
# Epoch 9 Batch 5400 Loss 0.4426
# Epoch 9 Batch 5500 Loss 0.4438
# Epoch 9 Batch 5600 Loss 0.4746
# Epoch 9 Batch 5700 Loss 0.4428
# Epoch 9 Batch 5800 Loss 0.4410
# Epoch 9 Batch 5900 Loss 0.4027
# Epoch 9 Batch 6000 Loss 0.4449
# Epoch 9 Batch 6100 Loss 0.4549
# Epoch 9 Batch 6200 Loss 0.4137
# Epoch 9 Loss 0.439874
# Time taken for 1 epoch 1590.2277526855469 sec
#
# Epoch 10 Batch 0 Loss 0.4856
# Epoch 10 Batch 100 Loss 0.4331
# Epoch 10 Batch 200 Loss 0.4067
# Epoch 10 Batch 300 Loss 0.4231
# Epoch 10 Batch 400 Loss 0.4393
# Epoch 10 Batch 500 Loss 0.4198
# Epoch 10 Batch 600 Loss 0.4229
# Epoch 10 Batch 700 Loss 0.4496
# Epoch 10 Batch 800 Loss 0.4215
# Epoch 10 Batch 900 Loss 0.4457
# Epoch 10 Batch 1000 Loss 0.4793
# Epoch 10 Batch 1100 Loss 0.4328
# Epoch 10 Batch 1200 Loss 0.4303
# Epoch 10 Batch 1300 Loss 0.4590
# Epoch 10 Batch 1400 Loss 0.4415
# Epoch 10 Batch 1500 Loss 0.4340
# Epoch 10 Batch 1600 Loss 0.4629
# Epoch 10 Batch 1700 Loss 0.4531
# Epoch 10 Batch 1800 Loss 0.4081
# Epoch 10 Batch 1900 Loss 0.4437
# Epoch 10 Batch 2000 Loss 0.4862
# Epoch 10 Batch 2100 Loss 0.3978
# Epoch 10 Batch 2200 Loss 0.4185
# Epoch 10 Batch 2300 Loss 0.4369
# Epoch 10 Batch 2400 Loss 0.4258
# Epoch 10 Batch 2500 Loss 0.4635
# Epoch 10 Batch 2600 Loss 0.4133
# Epoch 10 Batch 2700 Loss 0.4417
# Epoch 10 Batch 2800 Loss 0.4191
# Epoch 10 Batch 2900 Loss 0.4030
# Epoch 10 Batch 3000 Loss 0.4865
# Epoch 10 Batch 3100 Loss 0.4348
# Epoch 10 Batch 3200 Loss 0.4274
# Epoch 10 Batch 3300 Loss 0.4098
# Epoch 10 Batch 3400 Loss 0.4445
# Epoch 10 Batch 3500 Loss 0.4281
# Epoch 10 Batch 3600 Loss 0.4172
# Epoch 10 Batch 3700 Loss 0.4805
# Epoch 10 Batch 3800 Loss 0.4918
# Epoch 10 Batch 3900 Loss 0.4094
# Epoch 10 Batch 4000 Loss 0.4539
# Epoch 10 Batch 4100 Loss 0.4376
# Epoch 10 Batch 4200 Loss 0.4506
# Epoch 10 Batch 4300 Loss 0.4557
# Epoch 10 Batch 4400 Loss 0.4140
# Epoch 10 Batch 4500 Loss 0.4447
# Epoch 10 Batch 4600 Loss 0.4289
# Epoch 10 Batch 4700 Loss 0.4378
# Epoch 10 Batch 4800 Loss 0.4090
# Epoch 10 Batch 4900 Loss 0.4282
# Epoch 10 Batch 5000 Loss 0.4219
# Epoch 10 Batch 5100 Loss 0.4254
# Epoch 10 Batch 5200 Loss 0.4311
# Epoch 10 Batch 5300 Loss 0.4547
# Epoch 10 Batch 5400 Loss 0.4737
# Epoch 10 Batch 5500 Loss 0.4228
# Epoch 10 Batch 5600 Loss 0.4269
# Epoch 10 Batch 5700 Loss 0.4510
# Epoch 10 Batch 5800 Loss 0.4506
# Epoch 10 Batch 5900 Loss 0.3895
# Epoch 10 Batch 6000 Loss 0.4135
# Epoch 10 Batch 6100 Loss 0.3914
# Epoch 10 Batch 6200 Loss 0.4199
# Epoch 10 Loss 0.438457
# Time taken for 1 epoch 1607.4203522205353 sec
#
# Epoch 11 Batch 0 Loss 0.4272
# Epoch 11 Batch 100 Loss 0.4175
# Epoch 11 Batch 200 Loss 0.4221
# Epoch 11 Batch 300 Loss 0.4209
# Epoch 11 Batch 400 Loss 0.4182
# Epoch 11 Batch 500 Loss 0.4384
# Epoch 11 Batch 600 Loss 0.4446
# Epoch 11 Batch 700 Loss 0.4559
# Epoch 11 Batch 800 Loss 0.4451
# Epoch 11 Batch 900 Loss 0.4373
# Epoch 11 Batch 1000 Loss 0.4379
# Epoch 11 Batch 1100 Loss 0.4237
# Epoch 11 Batch 1200 Loss 0.4495
# Epoch 11 Batch 1300 Loss 0.4389
# Epoch 11 Batch 1400 Loss 0.4184
# Epoch 11 Batch 1500 Loss 0.4407
# Epoch 11 Batch 1600 Loss 0.4140
# Epoch 11 Batch 1700 Loss 0.4302
# Epoch 11 Batch 1800 Loss 0.4150
# Epoch 11 Batch 1900 Loss 0.4337
# Epoch 11 Batch 2000 Loss 0.4573
# Epoch 11 Batch 2100 Loss 0.5054
# Epoch 11 Batch 2200 Loss 0.4333
# Epoch 11 Batch 2300 Loss 0.4233
# Epoch 11 Batch 2400 Loss 0.4612
# Epoch 11 Batch 2500 Loss 0.4716
# Epoch 11 Batch 2600 Loss 0.4195
# Epoch 11 Batch 2700 Loss 0.4542
# Epoch 11 Batch 2800 Loss 0.4321
# Epoch 11 Batch 2900 Loss 0.4636
# Epoch 11 Batch 3000 Loss 0.4346
# Epoch 11 Batch 3100 Loss 0.4315
# Epoch 11 Batch 3200 Loss 0.4280
# Epoch 11 Batch 3300 Loss 0.4003
# Epoch 11 Batch 3400 Loss 0.4425
# Epoch 11 Batch 3500 Loss 0.4486
# Epoch 11 Batch 3600 Loss 0.4478
# Epoch 11 Batch 3700 Loss 0.4082
# Epoch 11 Batch 3800 Loss 0.4364
# Epoch 11 Batch 3900 Loss 0.4007
# Epoch 11 Batch 4000 Loss 0.4102
# Epoch 11 Batch 4100 Loss 0.4172
# Epoch 11 Batch 4200 Loss 0.4513
# Epoch 11 Batch 4300 Loss 0.4203
# Epoch 11 Batch 4400 Loss 0.4108
# Epoch 11 Batch 4500 Loss 0.4536
# Epoch 11 Batch 4600 Loss 0.4682
# Epoch 11 Batch 4700 Loss 0.4392
# Epoch 11 Batch 4800 Loss 0.4008
# Epoch 11 Batch 4900 Loss 0.4501
# Epoch 11 Batch 5000 Loss 0.4920
# Epoch 11 Batch 5100 Loss 0.4364
# Epoch 11 Batch 5200 Loss 0.4238
# Epoch 11 Batch 5300 Loss 0.4763
# Epoch 11 Batch 5400 Loss 0.4591
# Epoch 11 Batch 5500 Loss 0.4664
# Epoch 11 Batch 5600 Loss 0.4178
# Epoch 11 Batch 5700 Loss 0.4501
# Epoch 11 Batch 5800 Loss 0.5013
# Epoch 11 Batch 5900 Loss 0.4294
# Epoch 11 Batch 6000 Loss 0.4182
# Epoch 11 Batch 6100 Loss 0.4581
# Epoch 11 Batch 6200 Loss 0.3946
# Epoch 11 Loss 0.437027
# Time taken for 1 epoch 1600.0713636875153 sec
#
# Epoch 12 Batch 0 Loss 0.5016
# Epoch 12 Batch 100 Loss 0.4624
# Epoch 12 Batch 200 Loss 0.4546
# Epoch 12 Batch 300 Loss 0.4088
# Epoch 12 Batch 400 Loss 0.4226
# Epoch 12 Batch 500 Loss 0.4479
# Epoch 12 Batch 600 Loss 0.4650
# Epoch 12 Batch 700 Loss 0.4515
# Epoch 12 Batch 800 Loss 0.4314
# Epoch 12 Batch 900 Loss 0.4335
# Epoch 12 Batch 1000 Loss 0.4607
# Epoch 12 Batch 1100 Loss 0.4367
# Epoch 12 Batch 1200 Loss 0.4458
# Epoch 12 Batch 1300 Loss 0.4280
# Epoch 12 Batch 1400 Loss 0.4124
# Epoch 12 Batch 1500 Loss 0.4170
# Epoch 12 Batch 1600 Loss 0.4667
# Epoch 12 Batch 1700 Loss 0.4520
# Epoch 12 Batch 1800 Loss 0.4112
# Epoch 12 Batch 1900 Loss 0.4129
# Epoch 12 Batch 2000 Loss 0.4772
# Epoch 12 Batch 2100 Loss 0.4599
# Epoch 12 Batch 2200 Loss 0.4301
# Epoch 12 Batch 2300 Loss 0.4397
# Epoch 12 Batch 2400 Loss 0.4343
# Epoch 12 Batch 2500 Loss 0.4846
# Epoch 12 Batch 2600 Loss 0.4110
# Epoch 12 Batch 2700 Loss 0.4584
# Epoch 12 Batch 2800 Loss 0.4782
# Epoch 12 Batch 2900 Loss 0.4284
# Epoch 12 Batch 3000 Loss 0.4172
# Epoch 12 Batch 3100 Loss 0.4347
# Epoch 12 Batch 3200 Loss 0.4193
# Epoch 12 Batch 3300 Loss 0.4440
# Epoch 12 Batch 3400 Loss 0.3906
# Epoch 12 Batch 3500 Loss 0.4157
# Epoch 12 Batch 3600 Loss 0.4550
# Epoch 12 Batch 3700 Loss 0.4332
# Epoch 12 Batch 3800 Loss 0.4963
# Epoch 12 Batch 3900 Loss 0.4324
# Epoch 12 Batch 4000 Loss 0.4085
# Epoch 12 Batch 4100 Loss 0.4136
# Epoch 12 Batch 4200 Loss 0.4234
# Epoch 12 Batch 4300 Loss 0.4437
# Epoch 12 Batch 4400 Loss 0.4860
# Epoch 12 Batch 4500 Loss 0.4729
# Epoch 12 Batch 4600 Loss 0.4212
# Epoch 12 Batch 4700 Loss 0.4442
# Epoch 12 Batch 4800 Loss 0.4245
# Epoch 12 Batch 4900 Loss 0.4391
# Epoch 12 Batch 5000 Loss 0.4077
# Epoch 12 Batch 5100 Loss 0.4005
# Epoch 12 Batch 5200 Loss 0.4221
# Epoch 12 Batch 5300 Loss 0.4495
# Epoch 12 Batch 5400 Loss 0.4324
# Epoch 12 Batch 5500 Loss 0.4668
# Epoch 12 Batch 5600 Loss 0.4359
# Epoch 12 Batch 5700 Loss 0.4494
# Epoch 12 Batch 5800 Loss 0.4512
# Epoch 12 Batch 5900 Loss 0.4179
# Epoch 12 Batch 6000 Loss 0.4459
# Epoch 12 Batch 6100 Loss 0.4396
# Epoch 12 Batch 6200 Loss 0.4050
# Epoch 12 Loss 0.436396
# Time taken for 1 epoch 1595.9974658489227 sec
#
# Epoch 13 Batch 0 Loss 0.4368
# Epoch 13 Batch 100 Loss 0.4622
# Epoch 13 Batch 200 Loss 0.4253
# Epoch 13 Batch 300 Loss 0.4353
# Epoch 13 Batch 400 Loss 0.4394
# Epoch 13 Batch 500 Loss 0.4554
# Epoch 13 Batch 600 Loss 0.4114
# Epoch 13 Batch 700 Loss 0.4464
# Epoch 13 Batch 800 Loss 0.4252
# Epoch 13 Batch 900 Loss 0.4495
# Epoch 13 Batch 1000 Loss 0.4491
# Epoch 13 Batch 1100 Loss 0.4424
# Epoch 13 Batch 1200 Loss 0.4243
# Epoch 13 Batch 1300 Loss 0.4345
# Epoch 13 Batch 1400 Loss 0.5133
# Epoch 13 Batch 1500 Loss 0.4560
# Epoch 13 Batch 1600 Loss 0.4912
# Epoch 13 Batch 1700 Loss 0.4265
# Epoch 13 Batch 1800 Loss 0.4223
# Epoch 13 Batch 1900 Loss 0.4156
# Epoch 13 Batch 2000 Loss 0.4186
# Epoch 13 Batch 2100 Loss 0.4278
# Epoch 13 Batch 2200 Loss 0.4569
# Epoch 13 Batch 2300 Loss 0.4235
# Epoch 13 Batch 2400 Loss 0.4521
# Epoch 13 Batch 2500 Loss 0.4431
# Epoch 13 Batch 2600 Loss 0.4484
# Epoch 13 Batch 2700 Loss 0.4283
# Epoch 13 Batch 2800 Loss 0.4153
# Epoch 13 Batch 2900 Loss 0.4718
# Epoch 13 Batch 3000 Loss 0.4171
# Epoch 13 Batch 3100 Loss 0.4093
# Epoch 13 Batch 3200 Loss 0.4529
# Epoch 13 Batch 3300 Loss 0.4474
# Epoch 13 Batch 3400 Loss 0.4375
# Epoch 13 Batch 3500 Loss 0.4369
# Epoch 13 Batch 3600 Loss 0.4537
# Epoch 13 Batch 3700 Loss 0.4253
# Epoch 13 Batch 3800 Loss 0.4221
# Epoch 13 Batch 3900 Loss 0.4175
# Epoch 13 Batch 4000 Loss 0.4416
# Epoch 13 Batch 4100 Loss 0.4396
# Epoch 13 Batch 4200 Loss 0.4185
# Epoch 13 Batch 4300 Loss 0.4460
# Epoch 13 Batch 4400 Loss 0.4463
# Epoch 13 Batch 4500 Loss 0.4089
# Epoch 13 Batch 4600 Loss 0.4035
# Epoch 13 Batch 4700 Loss 0.4069
# Epoch 13 Batch 4800 Loss 0.4364
# Epoch 13 Batch 4900 Loss 0.4440
# Epoch 13 Batch 5000 Loss 0.4552
# Epoch 13 Batch 5100 Loss 0.4532
# Epoch 13 Batch 5200 Loss 0.4284
# Epoch 13 Batch 5300 Loss 0.3911
# Epoch 13 Batch 5400 Loss 0.4163
# Epoch 13 Batch 5500 Loss 0.4062
# Epoch 13 Batch 5600 Loss 0.4224
# Epoch 13 Batch 5700 Loss 0.4567
# Epoch 13 Batch 5800 Loss 0.4528
# Epoch 13 Batch 5900 Loss 0.4696
# Epoch 13 Batch 6000 Loss 0.4464
# Epoch 13 Batch 6100 Loss 0.4484
# Epoch 13 Batch 6200 Loss 0.4092
# Epoch 13 Loss 0.435254
# Time taken for 1 epoch 1600.178771495819 sec
#
# Epoch 14 Batch 0 Loss 0.4679
# Epoch 14 Batch 100 Loss 0.3916
# Epoch 14 Batch 200 Loss 0.4282
# Epoch 14 Batch 300 Loss 0.4440
# Epoch 14 Batch 400 Loss 0.5118
# Epoch 14 Batch 500 Loss 0.4150
# Epoch 14 Batch 600 Loss 0.4545
# Epoch 14 Batch 700 Loss 0.4302
# Epoch 14 Batch 800 Loss 0.4485
# Epoch 14 Batch 900 Loss 0.4133
# Epoch 14 Batch 1000 Loss 0.4214
# Epoch 14 Batch 1100 Loss 0.4137
# Epoch 14 Batch 1200 Loss 0.4808
# Epoch 14 Batch 1300 Loss 0.4080
# Epoch 14 Batch 1400 Loss 0.4393
# Epoch 14 Batch 1500 Loss 0.4125
# Epoch 14 Batch 1600 Loss 0.4474
# Epoch 14 Batch 1700 Loss 0.4642
# Epoch 14 Batch 1800 Loss 0.4387
# Epoch 14 Batch 1900 Loss 0.4275
# Epoch 14 Batch 2000 Loss 0.4575
# Epoch 14 Batch 2100 Loss 0.4317
# Epoch 14 Batch 2200 Loss 0.4495
# Epoch 14 Batch 2300 Loss 0.4320
# Epoch 14 Batch 2400 Loss 0.4311
# Epoch 14 Batch 2500 Loss 0.4599
# Epoch 14 Batch 2600 Loss 0.4079
# Epoch 14 Batch 2700 Loss 0.4033
# Epoch 14 Batch 2800 Loss 0.4359
# Epoch 14 Batch 2900 Loss 0.4384
# Epoch 14 Batch 3000 Loss 0.4134
# Epoch 14 Batch 3100 Loss 0.4046
# Epoch 14 Batch 3200 Loss 0.4471
# Epoch 14 Batch 3300 Loss 0.4483
# Epoch 14 Batch 3400 Loss 0.3935
# Epoch 14 Batch 3500 Loss 0.4613
# Epoch 14 Batch 3600 Loss 0.4706
# Epoch 14 Batch 3700 Loss 0.4294
# Epoch 14 Batch 3800 Loss 0.4204
# Epoch 14 Batch 3900 Loss 0.4573
# Epoch 14 Batch 4000 Loss 0.4558
# Epoch 14 Batch 4100 Loss 0.4326
# Epoch 14 Batch 4200 Loss 0.4152
# Epoch 14 Batch 4300 Loss 0.4308
# Epoch 14 Batch 4400 Loss 0.4621
# Epoch 14 Batch 4500 Loss 0.4575
# Epoch 14 Batch 4600 Loss 0.4241
# Epoch 14 Batch 4700 Loss 0.4340
# Epoch 14 Batch 4800 Loss 0.4075
# Epoch 14 Batch 4900 Loss 0.4391
# Epoch 14 Batch 5000 Loss 0.4699
# Epoch 14 Batch 5100 Loss 0.4307
# Epoch 14 Batch 5200 Loss 0.4209
# Epoch 14 Batch 5300 Loss 0.4013
# Epoch 14 Batch 5400 Loss 0.4087
# Epoch 14 Batch 5500 Loss 0.4500
# Epoch 14 Batch 5600 Loss 0.4675
# Epoch 14 Batch 5700 Loss 0.4480
# Epoch 14 Batch 5800 Loss 0.4751
# Epoch 14 Batch 5900 Loss 0.4176
# Epoch 14 Batch 6000 Loss 0.4246
# Epoch 14 Batch 6100 Loss 0.4502
# Epoch 14 Batch 6200 Loss 0.3961
# Epoch 14 Loss 0.436105
# Time taken for 1 epoch 1598.4067494869232 sec
#
# Epoch 15 Batch 0 Loss 0.4423
# Epoch 15 Batch 100 Loss 0.4360
# Epoch 15 Batch 200 Loss 0.4290
# Epoch 15 Batch 300 Loss 0.4284
# Epoch 15 Batch 400 Loss 0.4126
# Epoch 15 Batch 500 Loss 0.4244
# Epoch 15 Batch 600 Loss 0.4743
# Epoch 15 Batch 700 Loss 0.4667
# Epoch 15 Batch 800 Loss 0.4101
# Epoch 15 Batch 900 Loss 0.4497
# Epoch 15 Batch 1000 Loss 0.4268
# Epoch 15 Batch 1100 Loss 0.4085
# Epoch 15 Batch 1200 Loss 0.4650
# Epoch 15 Batch 1300 Loss 0.4012
# Epoch 15 Batch 1400 Loss 0.4699
# Epoch 15 Batch 1500 Loss 0.4648
# Epoch 15 Batch 1600 Loss 0.4323
# Epoch 15 Batch 1700 Loss 0.4573
# Epoch 15 Batch 1800 Loss 0.3787
# Epoch 15 Batch 1900 Loss 0.4605
# Epoch 15 Batch 2000 Loss 0.4448
# Epoch 15 Batch 2100 Loss 0.4397
# Epoch 15 Batch 2200 Loss 0.4490
# Epoch 15 Batch 2300 Loss 0.4530
# Epoch 15 Batch 2400 Loss 0.4447
# Epoch 15 Batch 2500 Loss 0.4288
# Epoch 15 Batch 2600 Loss 0.4460
# Epoch 15 Batch 2700 Loss 0.4632
# Epoch 15 Batch 2800 Loss 0.4138
# Epoch 15 Batch 2900 Loss 0.4355
# Epoch 15 Batch 3000 Loss 0.4427
# Epoch 15 Batch 3100 Loss 0.4579
# Epoch 15 Batch 3200 Loss 0.4250
# Epoch 15 Batch 3300 Loss 0.4580
# Epoch 15 Batch 3400 Loss 0.4285
# Epoch 15 Batch 3500 Loss 0.4796
# Epoch 15 Batch 3600 Loss 0.4196
# Epoch 15 Batch 3700 Loss 0.4267
# Epoch 15 Batch 3800 Loss 0.4559
# Epoch 15 Batch 3900 Loss 0.4048
# Epoch 15 Batch 4000 Loss 0.4480
# Epoch 15 Batch 4100 Loss 0.4369
# Epoch 15 Batch 4200 Loss 0.4454
# Epoch 15 Batch 4300 Loss 0.4304
# Epoch 15 Batch 4400 Loss 0.4091
# Epoch 15 Batch 4500 Loss 0.4283
# Epoch 15 Batch 4600 Loss 0.4490
# Epoch 15 Batch 4700 Loss 0.4484
# Epoch 15 Batch 4800 Loss 0.4056
# Epoch 15 Batch 4900 Loss 0.5371
# Epoch 15 Batch 5000 Loss 0.4783
# Epoch 15 Batch 5100 Loss 0.4370
# Epoch 15 Batch 5200 Loss 0.4446
# Epoch 15 Batch 5300 Loss 0.4032
# Epoch 15 Batch 5400 Loss 0.4592
# Epoch 15 Batch 5500 Loss 0.4195
# Epoch 15 Batch 5600 Loss 0.4560
# Epoch 15 Batch 5700 Loss 0.4367
# Epoch 15 Batch 5800 Loss 0.3929
# Epoch 15 Batch 5900 Loss 0.4101
# Epoch 15 Batch 6000 Loss 0.4595
# Epoch 15 Batch 6100 Loss 0.3922
# Epoch 15 Batch 6200 Loss 0.4334
# Epoch 15 Loss 0.433612
# Time taken for 1 epoch 1589.7313058376312 sec
#
# Epoch 16 Batch 0 Loss 0.4656
# Epoch 16 Batch 100 Loss 0.4288
# Epoch 16 Batch 200 Loss 0.4486
# Epoch 16 Batch 300 Loss 0.4130
# Epoch 16 Batch 400 Loss 0.4647
# Epoch 16 Batch 500 Loss 0.4183
# Epoch 16 Batch 600 Loss 0.4227
# Epoch 16 Batch 700 Loss 0.4039
# Epoch 16 Batch 800 Loss 0.4352
# Epoch 16 Batch 900 Loss 0.4224
# Epoch 16 Batch 1000 Loss 0.4495
# Epoch 16 Batch 1100 Loss 0.3985
# Epoch 16 Batch 1200 Loss 0.4482
# Epoch 16 Batch 1300 Loss 0.5192
# Epoch 16 Batch 1400 Loss 0.5246
# Epoch 16 Batch 1500 Loss 0.4685
# Epoch 16 Batch 1600 Loss 0.4773
# Epoch 16 Batch 1700 Loss 0.4349
# Epoch 16 Batch 1800 Loss 0.4187
# Epoch 16 Batch 1900 Loss 0.4466
# Epoch 16 Batch 2000 Loss 0.4309
# Epoch 16 Batch 2100 Loss 0.4811
# Epoch 16 Batch 2200 Loss 0.4081
# Epoch 16 Batch 2300 Loss 0.4623
# Epoch 16 Batch 2400 Loss 0.4394
# Epoch 16 Batch 2500 Loss 0.4800
# Epoch 16 Batch 2600 Loss 0.3957
# Epoch 16 Batch 2700 Loss 0.4442
# Epoch 16 Batch 2800 Loss 0.4048
# Epoch 16 Batch 2900 Loss 0.4139
# Epoch 16 Batch 3000 Loss 0.4001
# Epoch 16 Batch 3100 Loss 0.4400
# Epoch 16 Batch 3200 Loss 0.4320
# Epoch 16 Batch 3300 Loss 0.4758
# Epoch 16 Batch 3400 Loss 0.4234
# Epoch 16 Batch 3500 Loss 0.4705
# Epoch 16 Batch 3600 Loss 0.4333
# Epoch 16 Batch 3700 Loss 0.4138
# Epoch 16 Batch 3800 Loss 0.4457
# Epoch 16 Batch 3900 Loss 0.4415
# Epoch 16 Batch 4000 Loss 0.4368
# Epoch 16 Batch 4100 Loss 0.3725
# Epoch 16 Batch 4200 Loss 0.4455
# Epoch 16 Batch 4300 Loss 0.4289
# Epoch 16 Batch 4400 Loss 0.3860
# Epoch 16 Batch 4500 Loss 0.4174
# Epoch 16 Batch 4600 Loss 0.4999
# Epoch 16 Batch 4700 Loss 0.4423
# Epoch 16 Batch 4800 Loss 0.4326
# Epoch 16 Batch 4900 Loss 0.4348
# Epoch 16 Batch 5000 Loss 0.4714
# Epoch 16 Batch 5100 Loss 0.4511
# Epoch 16 Batch 5200 Loss 0.4547
# Epoch 16 Batch 5300 Loss 0.4293
# Epoch 16 Batch 5400 Loss 0.4421
# Epoch 16 Batch 5500 Loss 0.4376
# Epoch 16 Batch 5600 Loss 0.4357
# Epoch 16 Batch 5700 Loss 0.4319
# Epoch 16 Batch 5800 Loss 0.4206
# Epoch 16 Batch 5900 Loss 0.4706
# Epoch 16 Batch 6000 Loss 0.4200
# Epoch 16 Batch 6100 Loss 0.4308
# Epoch 16 Batch 6200 Loss 0.4131
# Epoch 16 Loss 0.435064
# Time taken for 1 epoch 1587.3580079078674 sec
#
# Epoch 17 Batch 0 Loss 0.4375
# Epoch 17 Batch 100 Loss 0.4553
# Epoch 17 Batch 200 Loss 0.4392
# Epoch 17 Batch 300 Loss 0.4466
# Epoch 17 Batch 400 Loss 0.4275
# Epoch 17 Batch 500 Loss 0.4754
# Epoch 17 Batch 600 Loss 0.4121
# Epoch 17 Batch 700 Loss 0.4482
# Epoch 17 Batch 800 Loss 0.4431
# Epoch 17 Batch 900 Loss 0.4472
# Epoch 17 Batch 1000 Loss 0.4462
# Epoch 17 Batch 1100 Loss 0.4128
# Epoch 17 Batch 1200 Loss 0.4047
# Epoch 17 Batch 1300 Loss 0.4418
# Epoch 17 Batch 1400 Loss 0.3918
# Epoch 17 Batch 1500 Loss 0.4172
# Epoch 17 Batch 1600 Loss 0.4760
# Epoch 17 Batch 1700 Loss 0.4601
# Epoch 17 Batch 1800 Loss 0.4817
# Epoch 17 Batch 1900 Loss 0.4510
# Epoch 17 Batch 2000 Loss 0.4143
# Epoch 17 Batch 2100 Loss 0.4896
# Epoch 17 Batch 2200 Loss 0.4520
# Epoch 17 Batch 2300 Loss 0.4384
# Epoch 17 Batch 2400 Loss 0.4498
# Epoch 17 Batch 2500 Loss 0.4309
# Epoch 17 Batch 2600 Loss 0.4171
# Epoch 17 Batch 2700 Loss 0.4305
# Epoch 17 Batch 2800 Loss 0.3939
# Epoch 17 Batch 2900 Loss 0.3932
# Epoch 17 Batch 3000 Loss 0.4077
# Epoch 17 Batch 3100 Loss 0.4436
# Epoch 17 Batch 3200 Loss 0.4490
# Epoch 17 Batch 3300 Loss 0.3953
# Epoch 17 Batch 3400 Loss 0.4318
# Epoch 17 Batch 3500 Loss 0.4441
# Epoch 17 Batch 3600 Loss 0.4194
# Epoch 17 Batch 3700 Loss 0.4156
# Epoch 17 Batch 3800 Loss 0.4236
# Epoch 17 Batch 3900 Loss 0.4269
# Epoch 17 Batch 4000 Loss 0.4168
# Epoch 17 Batch 4100 Loss 0.4148
# Epoch 17 Batch 4200 Loss 0.4128
# Epoch 17 Batch 4300 Loss 0.4375
# Epoch 17 Batch 4400 Loss 0.4301
# Epoch 17 Batch 4500 Loss 0.4092
# Epoch 17 Batch 4600 Loss 0.4234
# Epoch 17 Batch 4700 Loss 0.4236
# Epoch 17 Batch 4800 Loss 0.3940
# Epoch 17 Batch 4900 Loss 0.4319
# Epoch 17 Batch 5000 Loss 0.4219
# Epoch 17 Batch 5100 Loss 0.4352
# Epoch 17 Batch 5200 Loss 0.4315
# Epoch 17 Batch 5300 Loss 0.3831
# Epoch 17 Batch 5400 Loss 0.4958
# Epoch 17 Batch 5500 Loss 0.4680
# Epoch 17 Batch 5600 Loss 0.4134
# Epoch 17 Batch 5700 Loss 0.4266
# Epoch 17 Batch 5800 Loss 0.4273
# Epoch 17 Batch 5900 Loss 0.4341
# Epoch 17 Batch 6000 Loss 0.4075
# Epoch 17 Batch 6100 Loss 0.4508
# Epoch 17 Batch 6200 Loss 0.4428
# Epoch 17 Loss 0.432554
# Time taken for 1 epoch 1584.3964462280273 sec
#
# Epoch 18 Batch 0 Loss 0.4796
# Epoch 18 Batch 100 Loss 0.4193
# Epoch 18 Batch 200 Loss 0.4198
# Epoch 18 Batch 300 Loss 0.4315
# Epoch 18 Batch 400 Loss 0.4207
# Epoch 18 Batch 500 Loss 0.4210
# Epoch 18 Batch 600 Loss 0.4172
# Epoch 18 Batch 700 Loss 0.4476
# Epoch 18 Batch 800 Loss 0.4455
# Epoch 18 Batch 900 Loss 0.4035
# Epoch 18 Batch 1000 Loss 0.4131
# Epoch 18 Batch 1100 Loss 0.4021
# Epoch 18 Batch 1200 Loss 0.4237
# Epoch 18 Batch 1300 Loss 0.4321
# Epoch 18 Batch 1400 Loss 0.4513
# Epoch 18 Batch 1500 Loss 0.4179
# Epoch 18 Batch 1600 Loss 0.4217
# Epoch 18 Batch 1700 Loss 0.4398
# Epoch 18 Batch 1800 Loss 0.4415
# Epoch 18 Batch 1900 Loss 0.4307
# Epoch 18 Batch 2000 Loss 0.4638
# Epoch 18 Batch 2100 Loss 0.4155
# Epoch 18 Batch 2200 Loss 0.4311
# Epoch 18 Batch 2300 Loss 0.4241
# Epoch 18 Batch 2400 Loss 0.4770
# Epoch 18 Batch 2500 Loss 0.4467
# Epoch 18 Batch 2600 Loss 0.3729
# Epoch 18 Batch 2700 Loss 0.4683
# Epoch 18 Batch 2800 Loss 0.4570
# Epoch 18 Batch 2900 Loss 0.4771
# Epoch 18 Batch 3000 Loss 0.4505
# Epoch 18 Batch 3100 Loss 0.4469
# Epoch 18 Batch 3200 Loss 0.4659
# Epoch 18 Batch 3300 Loss 0.3879
# Epoch 18 Batch 3400 Loss 0.3984
# Epoch 18 Batch 3500 Loss 0.4263
# Epoch 18 Batch 3600 Loss 0.4098
# Epoch 18 Batch 3700 Loss 0.3867
# Epoch 18 Batch 3800 Loss 0.4207
# Epoch 18 Batch 3900 Loss 0.3920
# Epoch 18 Batch 4000 Loss 0.4059
# Epoch 18 Batch 4100 Loss 0.3761
# Epoch 18 Batch 4200 Loss 0.4857
# Epoch 18 Batch 4300 Loss 0.4180
# Epoch 18 Batch 4400 Loss 0.4168
# Epoch 18 Batch 4500 Loss 0.3969
# Epoch 18 Batch 4600 Loss 0.4509
# Epoch 18 Batch 4700 Loss 0.3841
# Epoch 18 Batch 4800 Loss 0.4604
# Epoch 18 Batch 4900 Loss 0.3661
# Epoch 18 Batch 5000 Loss 0.4133
# Epoch 18 Batch 5100 Loss 0.4465
# Epoch 18 Batch 5200 Loss 0.4015
# Epoch 18 Batch 5300 Loss 0.3916
# Epoch 18 Batch 5400 Loss 0.4137
# Epoch 18 Batch 5500 Loss 0.4512
# Epoch 18 Batch 5600 Loss 0.4041
# Epoch 18 Batch 5700 Loss 0.4232
# Epoch 18 Batch 5800 Loss 0.4334
# Epoch 18 Batch 5900 Loss 0.4284
# Epoch 18 Batch 6000 Loss 0.4385
# Epoch 18 Batch 6100 Loss 0.4085
# Epoch 18 Batch 6200 Loss 0.4293
# Epoch 18 Loss 0.431743
# Time taken for 1 epoch 1583.5637624263763 sec
#
# Epoch 19 Batch 0 Loss 0.4861
# Epoch 19 Batch 100 Loss 0.4255
# Epoch 19 Batch 200 Loss 0.4332
# Epoch 19 Batch 300 Loss 0.4165
# Epoch 19 Batch 400 Loss 0.4557
# Epoch 19 Batch 500 Loss 0.4213
# Epoch 19 Batch 600 Loss 0.3970
# Epoch 19 Batch 700 Loss 0.4643
# Epoch 19 Batch 800 Loss 0.4145
# Epoch 19 Batch 900 Loss 0.4025
# Epoch 19 Batch 1000 Loss 0.4317
# Epoch 19 Batch 1100 Loss 0.4434
# Epoch 19 Batch 1200 Loss 0.3804
# Epoch 19 Batch 1300 Loss 0.3979
# Epoch 19 Batch 1400 Loss 0.4150
# Epoch 19 Batch 1500 Loss 0.4332
# Epoch 19 Batch 1600 Loss 0.4146
# Epoch 19 Batch 1700 Loss 0.4631
# Epoch 19 Batch 1800 Loss 0.4313
# Epoch 19 Batch 1900 Loss 0.4310
# Epoch 19 Batch 2000 Loss 0.3874
# Epoch 19 Batch 2100 Loss 0.4325
# Epoch 19 Batch 2200 Loss 0.4495
# Epoch 19 Batch 2300 Loss 0.4235
# Epoch 19 Batch 2400 Loss 0.4679
# Epoch 19 Batch 2500 Loss 0.4059
# Epoch 19 Batch 2600 Loss 0.4559
# Epoch 19 Batch 2700 Loss 0.4679
# Epoch 19 Batch 2800 Loss 0.4150
# Epoch 19 Batch 2900 Loss 0.4049
# Epoch 19 Batch 3000 Loss 0.4360
# Epoch 19 Batch 3100 Loss 0.4137
# Epoch 19 Batch 3200 Loss 0.4298
# Epoch 19 Batch 3300 Loss 0.4072
# Epoch 19 Batch 3400 Loss 0.4006
# Epoch 19 Batch 3500 Loss 0.4378
# Epoch 19 Batch 3600 Loss 0.4095
# Epoch 19 Batch 3700 Loss 0.4218
# Epoch 19 Batch 3800 Loss 0.4297
# Epoch 19 Batch 3900 Loss 0.4198
# Epoch 19 Batch 4000 Loss 0.5181
# Epoch 19 Batch 4100 Loss 0.4090
# Epoch 19 Batch 4200 Loss 0.4233
# Epoch 19 Batch 4300 Loss 0.4404
# Epoch 19 Batch 4400 Loss 0.4258
# Epoch 19 Batch 4500 Loss 0.4384
# Epoch 19 Batch 4600 Loss 0.4493
# Epoch 19 Batch 4700 Loss 0.4101
# Epoch 19 Batch 4800 Loss 0.3830
# Epoch 19 Batch 4900 Loss 0.4688
# Epoch 19 Batch 5000 Loss 0.3900
# Epoch 19 Batch 5100 Loss 0.4512
# Epoch 19 Batch 5200 Loss 0.4497
# Epoch 19 Batch 5300 Loss 0.4488
# Epoch 19 Batch 5400 Loss 0.4480
# Epoch 19 Batch 5500 Loss 0.4457
# Epoch 19 Batch 5600 Loss 0.4586
# Epoch 19 Batch 5700 Loss 0.4011
# Epoch 19 Batch 5800 Loss 0.4532
# Epoch 19 Batch 5900 Loss 0.4383
# Epoch 19 Batch 6000 Loss 0.4233
# Epoch 19 Batch 6100 Loss 0.3886
# Epoch 19 Batch 6200 Loss 0.4126
# Epoch 19 Loss 0.431393
# Time taken for 1 epoch 1601.6199011802673 sec
#
# Epoch 20 Batch 0 Loss 0.4622
# Epoch 20 Batch 100 Loss 0.4309
# Epoch 20 Batch 200 Loss 0.4334
# Epoch 20 Batch 300 Loss 0.4297
# Epoch 20 Batch 400 Loss 0.4689
# Epoch 20 Batch 500 Loss 0.4509
# Epoch 20 Batch 600 Loss 0.4256
# Epoch 20 Batch 700 Loss 0.4162
# Epoch 20 Batch 800 Loss 0.4114
# Epoch 20 Batch 900 Loss 0.4054
# Epoch 20 Batch 1000 Loss 0.4152
# Epoch 20 Batch 1100 Loss 0.4308
# Epoch 20 Batch 1200 Loss 0.3777
# Epoch 20 Batch 1300 Loss 0.4457
# Epoch 20 Batch 1400 Loss 0.4397
# Epoch 20 Batch 1500 Loss 0.4490
# Epoch 20 Batch 1600 Loss 0.4342
# Epoch 20 Batch 1700 Loss 0.4591
# Epoch 20 Batch 1800 Loss 0.5262
# Epoch 20 Batch 1900 Loss 0.4854
# Epoch 20 Batch 2000 Loss 0.4709
# Epoch 20 Batch 2100 Loss 0.4376
# Epoch 20 Batch 2200 Loss 0.4092
# Epoch 20 Batch 2300 Loss 0.4415
# Epoch 20 Batch 2400 Loss 0.4146
# Epoch 20 Batch 2500 Loss 0.4352
# Epoch 20 Batch 2600 Loss 0.4527
# Epoch 20 Batch 2700 Loss 0.4300
# Epoch 20 Batch 2800 Loss 0.3877
# Epoch 20 Batch 2900 Loss 0.4357
# Epoch 20 Batch 3000 Loss 0.4058
# Epoch 20 Batch 3100 Loss 0.4644
# Epoch 20 Batch 3200 Loss 0.4122
# Epoch 20 Batch 3300 Loss 0.4143
# Epoch 20 Batch 3400 Loss 0.4261
# Epoch 20 Batch 3500 Loss 0.4286
# Epoch 20 Batch 3600 Loss 0.4613
# Epoch 20 Batch 3700 Loss 0.4326
# Epoch 20 Batch 3800 Loss 0.4092
# Epoch 20 Batch 3900 Loss 0.4421
# Epoch 20 Batch 4000 Loss 0.4411
# Epoch 20 Batch 4100 Loss 0.4201
# Epoch 20 Batch 4200 Loss 0.4470
# Epoch 20 Batch 4300 Loss 0.4563
# Epoch 20 Batch 4400 Loss 0.4308
# Epoch 20 Batch 4500 Loss 0.4176
# Epoch 20 Batch 4600 Loss 0.4605
# Epoch 20 Batch 4700 Loss 0.3701
# Epoch 20 Batch 4800 Loss 0.3794
# Epoch 20 Batch 4900 Loss 0.4089
# Epoch 20 Batch 5000 Loss 0.4526
# Epoch 20 Batch 5100 Loss 0.4399
# Epoch 20 Batch 5200 Loss 0.3888
# Epoch 20 Batch 5300 Loss 0.4476
# Epoch 20 Batch 5400 Loss 0.4635
# Epoch 20 Batch 5500 Loss 0.4507
# Epoch 20 Batch 5600 Loss 0.4403
# Epoch 20 Batch 5700 Loss 0.4650
# Epoch 20 Batch 5800 Loss 0.3990
# Epoch 20 Batch 5900 Loss 0.3858
# Epoch 20 Batch 6000 Loss 0.4680
# Epoch 20 Batch 6100 Loss 0.4564
# Epoch 20 Batch 6200 Loss 0.4141
# Epoch 20 Loss 0.430162
# Time taken for 1 epoch 1603.5285913944244 sec
#
# Epoch 21 Batch 0 Loss 0.4524
# Epoch 21 Batch 100 Loss 0.4008
# Epoch 21 Batch 200 Loss 0.4509
# Epoch 21 Batch 300 Loss 0.4331
# Epoch 21 Batch 400 Loss 0.4100
# Epoch 21 Batch 500 Loss 0.4255
# Epoch 21 Batch 600 Loss 0.4596

# %% [markdown]
# # 3.2 Test
# La fonction qui permet d'achever une étape d'evaluation pour le test est dans la cellule suivante.

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input, features, hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# Fonction permettant la représentation de l'attention au niveau de l'image
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for l in range(len_result):
        temp_att = np.resize(attention_plot[l], (8, 8))
        ax = fig.add_subplot(len_result//2, len_result//2, l+1)
        ax.set_title(result[l])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %% [markdown]
# L'affichage de quelques exemples sur le résultat retourné par l'évaluation.

# %%
# Affichage de quelques annotations dans le jeu de test
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
# image = 'train2014/phpZLHCE7.jpg'
real_caption = ' '.join([tokenizer.index_word[i]
                        for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)

Image.open(image)
# Out:
# Real Caption: <start> a tall tower with a clock saying it is <unk> <end>
# Prediction Caption: a tall clock tower with a clock on the top <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=426x640 at 0x20D4F120550>

# %% [markdown]
# Try it on your own images
# For fun, below you're provided a method you can use to caption your own images with the model you've just trained. Keep in mind, it was trained on a relatively small amount of data, and your images may be different from the training data (so be prepared for weird results!)
